# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount} units. New balance: {self.balance}")
        else:
            print("Deposit amount should be greater than zero.")

    def withdraw(self, amount):
        if 0 < amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount} units. New balance: {self.balance}")
        else:
            print("Withdrawal amount should be greater than zero and less than or equal to your balance.")

    def __str__(self):
        return f"Account Number: {self.account_number}, Account Holder Name: {self.account_holder_name}, Balance: {self.balance}"


account = BankAccount("1234567890", "John Doe", 1000)
print(account)
account.deposit(500)
account.withdraw(200)
print(account)
# Out:
# Account Number: 1234567890, Account Holder Name: John Doe, Balance: 1000
# Deposited 500 units. New balance: 1500
# Withdrew 200 units. New balance: 1300
# Account Number: 1234567890, Account Holder Name: John Doe, Balance: 1300

# %%
class Employee:
    def __init__(self, employe_name, employe_id, salary):
        self.employe_name= employe_name
        self.employe_id= employe_id
        self.salary= salary
    def bonus(self, bonus):
        self.salary+=bonus
        print(f"Salary after 1yr bonus will be {self.salary}")
    def __str__(self):
        return f"Employee Name: {self.employe_name}, Employee ID: {self.employe_id}, Salary: {self.salary}"



a= Employee('Aayush',4356, 35000)
print(a)
a.bonus(900)
# Out:
# Employee Name: Aayush, Employee ID: 4356, Salary: 35000
# Salary after 1yr bonus will be 35900

# %%
class Vehicle:
    def __init__(self, vehicle_id, model, is_available=True):
        self.vehicle_id = vehicle_id
        self.model = model
        self.is_available = is_available

    def __str__(self):
        availability = "Available" if self.is_available else "Not Available"
        return f"Vehicle ID: {self.vehicle_id}, Model: {self.model}, Status: {availability}"


class VehicleRentalSystem:
    def __init__(self):
        self.vehicles = []

    def add_vehicle(self, vehicle_id, model):
        vehicle = Vehicle(vehicle_id, model)
        self.vehicles.append(vehicle)

    def rent_vehicle(self, vehicle_id):
        for vehicle in self.vehicles:
            if vehicle.vehicle_id == vehicle_id:
                if vehicle.is_available:
                    vehicle.is_available = False
                    print(f"Vehicle {vehicle_id} has been rented.")
                else:
                    print(f"Vehicle {vehicle_id} is not available for rent.")
                return
        print(f"Vehicle {vehicle_id} not found.")

    def return_vehicle(self, vehicle_id):
        for vehicle in self.vehicles:
            if vehicle.vehicle_id == vehicle_id:
                if not vehicle.is_available:
                    vehicle.is_available = True
                    print(f"Vehicle {vehicle_id} has been returned.")
                else:
                    print(f"Vehicle {vehicle_id} is already available.")
                return
        print(f"Vehicle {vehicle_id} not found.")

    def display_available_vehicles(self):
        print("Available Vehicles:")
        for vehicle in self.vehicles:
            if vehicle.is_available:
                print(vehicle)


# Example usage:
if __name__ == "__main__":
    rental_system = VehicleRentalSystem()

    # Adding vehicles to the rental system
    rental_system.add_vehicle("001", "Toyota Corolla")
    rental_system.add_vehicle("002", "Honda Civic")

    # Renting a vehicle
    rental_system.rent_vehicle("001")

    # Displaying available vehicles
    rental_system.display_available_vehicles()

    # Returning a vehicle
    rental_system.return_vehicle("001")

    # Displaying available vehicles after returning
    rental_system.display_available_vehicles()
# Out:
# Vehicle 001 has been rented.
# Available Vehicles:
# Vehicle ID: 002, Model: Honda Civic, Status: Available
# Vehicle 001 has been returned.
# Available Vehicles:
# Vehicle ID: 001, Model: Toyota Corolla, Status: Available
# Vehicle ID: 002, Model: Honda Civic, Status: Available

# %%
class Book:
    def __init__(self, title, author, book_id):
        self.title = title
        self.author = author
        self.book_id = book_id
        self.is_available = True

    def __str__(self):
        availability = "Available" if self.is_available else "Not Available"
        return f"Book ID: {self.book_id}, Title: {self.title}, Author: {self.author}, Status: {availability}"


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, title, author, book_id):
        book = Book(title, author, book_id)
        self.books.append(book)

    def borrow_book(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                if book.is_available:
                    book.is_available = False
                    print(f"Book '{book.title}' has been borrowed.")
                else:
                    print(f"Book '{book.title}' is not available.")
                return
        print("Book not found.")

    def return_book(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                if not book.is_available:
                    book.is_available = True
                    print(f"Book '{book.title}' has been returned.")
                else:
                    print(f"Book '{book.title}' is already available.")
                return
        print("Book not found.")

    def display_available_books(self):
        print("Available Books:")
        for book in self.books:
            if book.is_available:
                print(book)


# Example usage:
if __name__ == "__main__":
    library = Library()

    # Adding books to the library
    library.add_book("The Great Gatsby", "F. Scott Fitzgerald", "001")
    library.add_book("To Kill a Mockingbird", "Harper Lee", "002")

    # Borrowing a book
    library.borrow_book("001")

    # Displaying available books
    library.display_available_books()

    # Returning a book
    library.return_book("001")

    # Displaying available books after returning
    library.display_available_books()
# Out:
# Book 'The Great Gatsby' has been borrowed.
# Available Books:
# Book ID: 002, Title: To Kill a Mockingbird, Author: Harper Lee, Status: Available
# Book 'The Great Gatsby' has been returned.
# Available Books:
# Book ID: 001, Title: The Great Gatsby, Author: F. Scott Fitzgerald, Status: Available
# Book ID: 002, Title: To Kill a Mockingbird, Author: Harper Lee, Status: Available

# %%
class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity

    def __str__(self):
        return f"Product ID: {self.product_id}, Name: {self.name}, Price: {self.price}, Quantity: {self.quantity}"


class InventorySystem:
    def __init__(self):
        self.products = []

    def add_product(self, product_id, name, price, quantity):
        product = Product(product_id, name, price, quantity)
        self.products.append(product)

    def update_product_quantity(self, product_id, new_quantity):
        for product in self.products:
            if product.product_id == product_id:
                product.quantity = new_quantity
                print(f"Quantity of product '{product.name}' updated to {new_quantity}.")
                return
        print("Product not found.")

    def display_available_products(self):
        print("Available Products:")
        for product in self.products:
            print(product)


# Example usage:
if __name__ == "__main__":
    inventory_system = InventorySystem()

    # Adding products to the inventory
    inventory_system.add_product("001", "Laptop", 999, 10)
    inventory_system.add_product("002", "Smartphone", 599, 20)

    # Displaying available products
    inventory_system.display_available_products()

    # Updating product quantity
    inventory_system.update_product_quantity("001", 8)

    # Displaying available products after updating quantity
    inventory_system.display_available_products()
# Out:
# Available Products:
# Product ID: 001, Name: Laptop, Price: 999, Quantity: 10
# Product ID: 002, Name: Smartphone, Price: 599, Quantity: 20
# Quantity of product 'Laptop' updated to 8.
# Available Products:
# Product ID: 001, Name: Laptop, Price: 999, Quantity: 8
# Product ID: 002, Name: Smartphone, Price: 599, Quantity: 20

# %%
class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height

    def area(self):
        raise NotImplementedError("Subclasses must implement area method.")

    def perimeter(self):
        raise NotImplementedError("Subclasses must implement perimeter method.")


class Rectangle(Shape):
    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)


class Triangle(Shape):
    def __init__(self, base=0, height=0, side1=0, side2=0, side3=0):
        super().__init__(length=base, height=height)
        self.base = base
        self.height = height
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    def area(self):
        return 0.5 * self.base * self.height

    def perimeter(self):
        return self.side1 + self.side2 + self.side3


# Example usage:
if __name__ == "__main__":
    rectangle = Rectangle(length=5, width=4)
    print("Rectangle:")
    print("Area:", rectangle.area())
    print("Perimeter:", rectangle.perimeter())

    triangle = Triangle(base=6, height=4, side1=3, side2=4, side3=5)
    print("\nTriangle:")
    print("Area:", triangle.area())
    print("Perimeter:", triangle.perimeter())
# Out:
# Rectangle:
# Area: 20
# Perimeter: 18
#
# Triangle:
# Area: 12.0
# Perimeter: 12

# %%
class Student:
    def __init__(self, student_id, name):
        self.student_id = student_id
        self.name = name
        self.grades = []

    def add_grade(self, grade):
        self.grades.append(grade)

    def calculate_average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

    def display_details(self):
        print("Student ID:", self.student_id)
        print("Name:", self.name)
        print("Grades:", self.grades)
        print("Average Grade:", self.calculate_average_grade())


# Example usage:
if __name__ == "__main__":
    student1 = Student("001", "John Doe")
    student1.add_grade(90)
    student1.add_grade(85)
    student1.add_grade(92)

    student2 = Student("002", "Jane Smith")
    student2.add_grade(80)
    student2.add_grade(75)
    student2.add_grade(88)

    print("Student 1 Details:")
    student1.display_details()

    print("\nStudent 2 Details:")
    student2.display_details()
# Out:
# Student 1 Details:
# Student ID: 001
# Name: John Doe
# Grades: [90, 85, 92]
# Average Grade: 89.0
#
# Student 2 Details:
# Student ID: 002
# Name: Jane Smith
# Grades: [80, 75, 88]
# Average Grade: 81.0

# %%
class Email:
    def __init__(self, sender, recipient, subject, message):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.message = message

    def send_email(self):
        print(f"Email sent from {self.sender} to {self.recipient} with subject '{self.subject}'.")

    def display_details(self):
        print("Email Details:")
        print("Sender:", self.sender)
        print("Recipient:", self.recipient)
        print("Subject:", self.subject)
        print("Message:", self.message)


# Example usage:
if __name__ == "__main__":
    email = Email("sender@example.com", "recipient@example.com", "Test Email", "This is a test email message.")
    email.send_email()
    email.display_details()
# Out:
# Email sent from sender@example.com to recipient@example.com with subject 'Test Email'.
# Email Details:
# Sender: sender@example.com
# Recipient: recipient@example.com
# Subject: Test Email
# Message: This is a test email message.

# %%
class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, post):
        self.posts.append(post)

    def display_posts(self):
        print(f"Posts by {self.username}:")
        for post in self.posts:
            print(post)

    def search_posts_by_keyword(self, keyword):
        found_posts = [post for post in self.posts if keyword in post]
        if found_posts:
            print(f"Posts containing '{keyword}':")
            for post in found_posts:
                print(post)
        else:
            print(f"No posts containing '{keyword}' found.")


# Example usage:
if __name__ == "__main__":
    profile = SocialMediaProfile("user123")

    profile.add_post("Just finished reading a great book!")
    profile.add_post("Spent the day hiking in the mountains.")
    profile.add_post("Trying out a new recipe for dinner tonight.")

    profile.display_posts()

    profile.search_posts_by_keyword("hiking")
# Out:
# Posts by user123:
# Just finished reading a great book!
# Spent the day hiking in the mountains.
# Trying out a new recipe for dinner tonight.
# Posts containing 'hiking':
# Spent the day hiking in the mountains.

# %%
class ToDoList:
    def __init__(self):
        self.tasks = {}

    def add_task(self, task, due_date):
        self.tasks[task] = due_date

    def mark_task_as_completed(self, task):
        if task in self.tasks:
            del self.tasks[task]
            print(f"Task '{task}' marked as completed.")
        else:
            print(f"Task '{task}' not found.")

    def display_pending_tasks(self):
        print("Pending Tasks:")
        for task, due_date in self.tasks.items():
            print(f"Task: {task} (Due Date: {due_date})")


# Example usage:
if __name__ == "__main__":
    todo_list = ToDoList()

    todo_list.add_task("Complete assignment", "2024-02-15")
    todo_list.add_task("Buy groceries", "2024-02-17")
    todo_list.add_task("Call mom", "2024-02-20")

    todo_list.display_pending_tasks()

    todo_list.mark_task_as_completed("Complete assignment")

    todo_list.display_pending_tasks()
# Out:
# Pending Tasks:
# Task: Complete assignment (Due Date: 2024-02-15)
# Task: Buy groceries (Due Date: 2024-02-17)
# Task: Call mom (Due Date: 2024-02-20)
# Task 'Complete assignment' marked as completed.
# Pending Tasks:
# Task: Buy groceries (Due Date: 2024-02-17)
# Task: Call mom (Due Date: 2024-02-20)
